# %% [markdown]
# # Exemple A du TP1 - Analyse Numerique

# %%
# importer la bibliotheque numy afin de faciliter la manipulation des  vecteurs et des matrices et beneficier de l'auto-completion

# %%
import numpy as  np

# %%
# Definir un vecteur X et une matrice A

# %%
X = np.array([-4,0,3])
print (X)
# Out:
# [-4  0  3]

# %%
A = np.array([[2,3],[-1,1]])
print(A)
# Out:
# [[ 2  3]
#  [-1  1]]

# %%
#Calculer la norme 1 - version automatique
norme1_X = np.linalg.norm(X,ord=1)
print (norme1_X)
# Out:
# 7.0

# %%
norme1_A = np.linalg.norm(A,ord=1)
print (norme1_A)
# Out:
# 4.0

# %%
# Calculer norme 2

# %%
norme2_X = np.linalg.norm(X,ord=2)
print (norme2_X)
# Out:
# 5.0

# %%
norme2_A = np.linalg.norm(A,ord=2)
print (norme2_A)
# Out:
# 3.618033988749894

# %%
# Déterminer le conditionnement de  A

# %%
invA = np.linalg.inv(A)
print (invA)
# Out:
# [[ 0.2 -0.6]
#  [ 0.2  0.4]]

# %%
norme2_invA=np.linalg.norm(invA,ord=2)
print (norme2_invA)
# Out:
# 0.7236067977499792

# %%
cond_A = norme2_A * norme2_invA
print(cond_A)
# Out:
# 2.618033988749895

# %%
# Methode directe pour calculer le conditionnement

# %%
np.linalg.cond(A,p=2)
# Out:
# np.float64(2.6180339887498936)
